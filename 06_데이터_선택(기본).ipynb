# %% [markdown]
# <a href="https://colab.research.google.com/github/leegr02/pandas/blob/main/06_%EB%8D%B0%EC%9D%B4%ED%84%B0_%EC%84%A0%ED%83%9D(%EA%B8%B0%EB%B3%B8).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 6. 데이터 선택

# %%
import pandas as pd
df=pd.read_excel('score.xlsx', index_col='지원번호')
df

# %% [markdown]
# ## Column 선택(label)

# %%
df['이름']

# %%
df['키']

# %%
df[['이름','키']]

# %% [markdown]
# ## Column 선택(정수 index)

# %%
df.columns

# %%
df.columns[0]

# %%
df.columns[2]

# %%
df[df.columns[0]] #df['이름']과 동일한 동작

# %%
df[df.columns[-1]] #맨 끝에 있는 값을 가져옴

# %% [markdown]
# ## 슬라이싱

# %%
df

# %%
df['영어'][0:5] #0-4까지 영어 점수 데이터 가져옴

# %%
df[['이름','키']][:3] #처음 3명의 이름, 키 정보를 가져옴

# %%
df[3:]
